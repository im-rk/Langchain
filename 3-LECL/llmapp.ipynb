# %%
import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key=os.getenv("GROQ_API_KEY")

# %%
# !pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Downloading langchain_groq-1.0.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain_groq)
#   Downloading groq-0.33.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langchain_groq) (1.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.12.3)
# Requirement already satisfied: sniffio in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.3.0)
# Requirement already satisfied: idna>=2.8 in d:\gen-ai\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.11)
# Requirement already satisfied: certifi in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\gen-ai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (0.4.39)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen-ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen-ai\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\gen-ai\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen-ai\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (2.3.0)
# Downloading langchain_groq-1.0.0-py3-none-any.whl (16 kB)
# Downloading groq-0.33.0-py3-none-any.whl (135 kB)
# Installing collected packages: groq, langchain_groq
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 2/2 [langchain_groq]
#
# Successfully installed groq-0.33.0 langchain_groq-1.0.0

# %%
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.1-8b-instant",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000023ADB95AD70>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000023ADB993670>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# !pip install langchain_core
# Out:
# Requirement already satisfied: langchain_core in d:\gen-ai\venv\lib\site-packages (1.0.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen-ai\venv\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen-ai\venv\lib\site-packages (from langchain_core) (0.4.39)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from langchain_core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\gen-ai\venv\lib\site-packages (from langchain_core) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\gen-ai\venv\lib\site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\gen-ai\venv\lib\site-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen-ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: anyio in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (4.11.0)
# Requirement already satisfied: certifi in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\gen-ai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\gen-ai\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage(content="Translate the following from English to French"),
    HumanMessage(content="Hello How are you ?")
]

result=model.invoke(messages)

# %%
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()
parser.invoke(result)
# Out:
# 'Bonjour comment allez-vous ? \n\n(Note: A more common way to ask "How are you?" in French is "Comment ça va?" but "comment allez-vous" is also acceptable, especially in more formal situations.)'

# %%
#using lecl chain of components
chain=model|parser
chain.invoke(messages)
# Out:
# 'Bonjour Comment allez-vous ?'

# %%
from langchain_core.prompts import ChatPromptTemplate

generic_template="Translate the following into {language}"

prompt=ChatPromptTemplate([
    ("system",generic_template),("user","{text}")
])

# %%
result=prompt.invoke({"language":"French","text":"Hello"})

# %%
result.to_messages
# Out:
# <bound method ChatPromptValue.to_messages of ChatPromptValue(messages=[SystemMessage(content='Translate the following into French', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello', additional_kwargs={}, response_metadata={})])>

# %%
chain=prompt|model|parser
chain.invoke({"language":"French","text":"Hello"})
# Out:
# 'Bonjour'
