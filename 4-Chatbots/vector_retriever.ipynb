# %%
# !pip install langchain
# !pip install langchain-chroma
# !pip install langchain_groq
# Out:
# Requirement already satisfied: langchain in d:\gen-ai\venv\lib\site-packages (1.0.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in d:\gen-ai\venv\lib\site-packages (from langchain) (1.0.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\gen-ai\venv\lib\site-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (0.4.39)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen-ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in d:\gen-ai\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in d:\gen-ai\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in d:\gen-ai\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in d:\gen-ai\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in d:\gen-ai\venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.11.0)
# Requirement already satisfied: httpx>=0.25.2 in d:\gen-ai\venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in d:\gen-ai\venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\gen-ai\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in d:\gen-ai\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\gen-ai\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\gen-ai\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\gen-ai\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain) (2.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\gen-ai\venv\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Requirement already satisfied: langchain-chroma in d:\gen-ai\venv\lib\site-packages (1.0.0)
# Requirement already satisfied: chromadb<2.0.0,>=1.0.20 in d:\gen-ai\venv\lib\site-packages (from langchain-chroma) (1.3.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langchain-chroma) (1.0.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\gen-ai\venv\lib\site-packages (from langchain-chroma) (2.2.6)
# Requirement already satisfied: build>=1.0.3 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.12.3)
# Requirement already satisfied: pybase64>=1.4.1 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\gen-ai\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\gen-ai\venv\lib\site-packages (from chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.25.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-chroma) (0.4.39)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-chroma) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen-ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-chroma) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in d:\gen-ai\venv\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.11.0)
# Requirement already satisfied: certifi in d:\gen-ai\venv\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\gen-ai\venv\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in d:\gen-ai\venv\lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\gen-ai\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in d:\gen-ai\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in d:\gen-ai\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen-ai\venv\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\gen-ai\venv\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen-ai\venv\lib\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-chroma) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-chroma) (2.3.0)
# Requirement already satisfied: pyproject_hooks in d:\gen-ai\venv\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\ramku\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.6 in d:\gen-ai\venv\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (8.7.0)
# Requirement already satisfied: tomli>=1.1.0 in d:\gen-ai\venv\lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.3.0)
# Requirement already satisfied: zipp>=3.20 in d:\gen-ai\venv\lib\site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\gen-ai\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\gen-ai\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\gen-ai\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\gen-ai\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.28.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\gen-ai\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.42.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\gen-ai\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in d:\gen-ai\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in d:\gen-ai\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in d:\gen-ai\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\gen-ai\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\gen-ai\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\gen-ai\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.6.1)
# Requirement already satisfied: coloredlogs in d:\gen-ai\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\gen-ai\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (25.9.23)
# Requirement already satisfied: protobuf in d:\gen-ai\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (6.33.0)
# Requirement already satisfied: sympy in d:\gen-ai\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in d:\gen-ai\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in d:\gen-ai\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in d:\gen-ai\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in d:\gen-ai\venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\gen-ai\venv\lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\gen-ai\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in d:\gen-ai\venv\lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.36.0)
# Requirement already satisfied: filelock in d:\gen-ai\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\gen-ai\venv\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.0.20->langchain-chroma) (2025.10.0)
# Requirement already satisfied: click>=8.0.0 in d:\gen-ai\venv\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in d:\gen-ai\venv\lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in d:\gen-ai\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in d:\gen-ai\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in d:\gen-ai\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in d:\gen-ai\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from anyio->httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\gen-ai\venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in d:\gen-ai\venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in d:\gen-ai\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\gen-ai\venv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.0.20->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\gen-ai\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: langchain_groq in d:\gen-ai\venv\lib\site-packages (1.0.0)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in d:\gen-ai\venv\lib\site-packages (from langchain_groq) (0.33.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langchain_groq) (1.0.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.12.3)
# Requirement already satisfied: sniffio in d:\gen-ai\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.3.0)
# Requirement already satisfied: idna>=2.8 in d:\gen-ai\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.11)
# Requirement already satisfied: certifi in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\gen-ai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (0.4.39)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_groq) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen-ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen-ai\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\gen-ai\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen-ai\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen-ai\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_groq) (2.3.0)

# %%
from langchain_core.documents import Document

documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Goldfish are popular pets for beginners, requiring relatively simple care.",
        metadata={"source": "fish-pets-doc"},
    ),
    Document(
        page_content="Parrots are intelligent birds capable of mimicking human speech.",
        metadata={"source": "bird-pets-doc"},
    ),
    Document(
        page_content="Rabbits are social animals that need plenty of space to hop around.",
        metadata={"source": "mammal-pets-doc"},
    ),
]

# %%
documents
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'fish-pets-doc'}, page_content='Goldfish are popular pets for beginners, requiring relatively simple care.'),
#  Document(metadata={'source': 'bird-pets-doc'}, page_content='Parrots are intelligent birds capable of mimicking human speech.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Rabbits are social animals that need plenty of space to hop around.')]

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq
groq_api_key=os.getenv("GROQ_API_KEY")

llm=ChatGroq(groq_api_key=groq_api_key,model="llama-3.1-8b-instant")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x00000268A7ECEEC0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000268A7ECEDD0>, model_name='llama-3.1-8b-instant', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# !pip install langchain_huggingface
# Out:
# Requirement already satisfied: langchain_huggingface in d:\gen-ai\venv\lib\site-packages (1.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.33.4 in d:\gen-ai\venv\lib\site-packages (from langchain_huggingface) (0.36.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.3 in d:\gen-ai\venv\lib\site-packages (from langchain_huggingface) (1.0.3)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in d:\gen-ai\venv\lib\site-packages (from langchain_huggingface) (0.22.1)
# Requirement already satisfied: filelock in d:\gen-ai\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\gen-ai\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2025.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in d:\gen-ai\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: requests in d:\gen-ai\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in d:\gen-ai\venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (0.4.39)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (2.12.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\gen-ai\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen-ai\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen-ai\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (0.25.0)
# Requirement already satisfied: anyio in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (4.11.0)
# Requirement already satisfied: certifi in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in d:\gen-ai\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\gen-ai\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen-ai\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen-ai\venv\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen-ai\venv\lib\site-packages (from requests->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (2.3.0)
# Requirement already satisfied: colorama in c:\users\ramku\appdata\roaming\python\python310\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.33.4->langchain_huggingface) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ramku\appdata\roaming\python\python310\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in d:\gen-ai\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.3->langchain_huggingface) (1.3.1)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
##vector stores

from langchain_chroma import Chroma

vectorstore=Chroma.from_documents(documents,embeddings)
vectorstore

# %%
vectorstore.similarity_search("cat")
# Out:
# [Document(id='4d6962fb-d5c0-4a7d-b142-c52295c9166e', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(id='c4976c8f-7800-4f18-859b-735c5761a10e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(id='7eaa25d2-2d70-4899-99b2-1b8d10081e70', metadata={'source': 'mammal-pets-doc'}, page_content='Rabbits are social animals that need plenty of space to hop around.'),
#  Document(id='451d88da-b25f-489c-be7d-d360d8ba54e0', metadata={'source': 'bird-pets-doc'}, page_content='Parrots are intelligent birds capable of mimicking human speech.')]

# %%
##async query

await vectorstore.asimilarity_search("cat")
# Out:
# [Document(id='4d6962fb-d5c0-4a7d-b142-c52295c9166e', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(id='c4976c8f-7800-4f18-859b-735c5761a10e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(id='7eaa25d2-2d70-4899-99b2-1b8d10081e70', metadata={'source': 'mammal-pets-doc'}, page_content='Rabbits are social animals that need plenty of space to hop around.'),
#  Document(id='451d88da-b25f-489c-be7d-d360d8ba54e0', metadata={'source': 'bird-pets-doc'}, page_content='Parrots are intelligent birds capable of mimicking human speech.')]

# %%
from typing import List

from langchain_core.documents import Document
from langchain_core.runnables  import RunnableLambda

retriver=RunnableLambda(vectorstore.similarity_search).bind(k=1)
retriver.batch(["cat","dog"])
# Out:
# [[Document(id='4d6962fb-d5c0-4a7d-b142-c52295c9166e', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.')],
#  [Document(id='c4976c8f-7800-4f18-859b-735c5761a10e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]]

# %%
retriver=vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k":1}
)
retriver.batch(["cat","dog"])
# Out:
# [[Document(id='4d6962fb-d5c0-4a7d-b142-c52295c9166e', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.')],
#  [Document(id='c4976c8f-7800-4f18-859b-735c5761a10e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]]

# %%
## RAG
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

message = """
Answer this question using the provided context only.

{question}

Context:
{context}
"""
prompt = ChatPromptTemplate.from_messages([("human", message)])

rag_chain={"context":retriver,"question":RunnablePassthrough()}|prompt|llm

response=rag_chain.invoke("tell me about dogs")
print(response.content)
# Out:
# Dogs are great companions, known for their loyalty and friendliness.
